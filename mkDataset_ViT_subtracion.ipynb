# %% [markdown]
# #Import library

# %%
## single frame analysis: whether there are large spatta?
import cv2
from IPython import display
from matplotlib import pyplot as plt
import time
from numpy import dtype,uint8
import scipy.ndimage as ndimage
import glob
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #Check number of images

# %% [markdown]
# #20220401

# %%
dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401'
def checkNum(dir=dir,date_20221020=False):
    for i in range(1,13):
        for j in range(1,3):
            if date_20221020 :
                src_img_dir = os.path.join(dir,"{}\crop".format((i-1)*2+j+20))
            else:
                #get num of file in a directory
                src_img_dir = os.path.join(dir,"{}_{}\crop".format(i,j))

            num_photo = sum(os.path.isfile(os.path.join(src_img_dir,name)) for name in os.listdir(src_img_dir))

            print(f"({i},{j})::",num_photo)

checkNum()
# Out:
# (1,1):: 540
# (1,2):: 537
# (2,1):: 1080
# (2,2):: 1079
# (3,1):: 2162
# (3,2):: 2162
# (4,1):: 540
# (4,2):: 540
# (5,1):: 1080
# (5,2):: 1081
# (6,1):: 2163
# (6,2):: 2162
# (7,1):: 540
# (7,2):: 540
# (8,1):: 1082
# (8,2):: 1079
# (9,1):: 2161
# (9,2):: 2162
# (10,1):: 540
# (10,2):: 540
# (11,1):: 1080
# (11,2):: 1080
# (12,1):: 2161
# (12,2):: 2092

# %% [markdown]
# #20220603

# %%
DIR_20220603 = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220603'
checkNum(dir = DIR_20220603)
# Out:
# (1,1):: 540
# (1,2):: 533
# (2,1):: 1079
# (2,2):: 1080
# (3,1):: 2162
# (3,2):: 2163
# (4,1):: 457
# (4,2):: 540
# (5,1):: 1079
# (5,2):: 1080
# (6,1):: 2162
# (6,2):: 2162
# (7,1):: 541
# (7,2):: 540
# (8,1):: 1080
# (8,2):: 1080
# (9,1):: 2162
# (9,2):: 2163
# (10,1):: 539
# (10,2):: 539
# (11,1):: 1080
# (11,2):: 1079
# (12,1):: 2162
# (12,2):: 2162

# %% [markdown]
# #20221020

# %%
DIR_20221020 = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020'
checkNum(dir = DIR_20221020,date_20221020=True)
# Out:
# (1,1):: 244
# (1,2):: 448
# (2,1):: 895
# (2,2):: 245
# (3,1):: 448
# (3,2):: 863
# (4,1):: 235
# (4,2):: 430
# (5,1):: 857
# (5,2):: 233
# (6,1):: 312
# (6,2):: 880
# (7,1):: 236
# (7,2):: 434
# (8,1):: 866
# (8,2):: 240
# (9,1):: 440
# (9,2):: 883
# (10,1):: 240
# (10,2):: 442
# (11,1):: 889
# (11,2):: 242
# (12,1):: 447
# (12,2):: 892

# %% [markdown]
# # subtract imgs

# %%
import os
import glob 

def subtractImgs(section,division,date):
    if date == "20221020":
        rootDir = r"C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\{date}\{section}\crop".format(date=date,section=section*2+division+18)
    else:
        rootDir = r"C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\{date}\{section}_{division}\crop".format(date=date,section=section,division=division)
    saveDir = os.path.join(rootDir,"subtraction")
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)
    #フォルダに存在するファイルを取得する、0001.jpg~0005.jpg→{}/*.jpg
    src_files=glob.glob("{}/*.jpg".format(rootDir))
    src_files.sort()
    count = 0
    for i,file in enumerate(src_files): #index,components=enumerate(file)
        if i%50 == 0:
            print(i,"::",file)
            imgIndex = int((file.split("\\")[-1]).split(".")[0])
            print(imgIndex)

        if i == 0:
            imgIndex = int((file.split("\\")[-1]).split(".")[0])
            oldImg = cv2.imread(file,0)
        else:
            if count==2:
                break
            imgIndex = int((file.split("\\")[-1]).split(".")[0])
            img = cv2.imread(file,0)
            imgSubtract = cv2.absdiff(img,oldImg)
            #print(imgSubtract)
            cv2.imwrite(os.path.join(saveDir,f"{imgIndex:04d}.jpg"),imgSubtract)
            oldImg = img.copy()

# %%
date = "20220401"
print("[[[ 20220401 ]]]")
for i in range(1,13):
    print(i,"-",1)
    subtractImgs(i,1,date=date)
    print(i,"-",2)
    subtractImgs(i,2,date=date)
date = "20220603"
print("[[[ 20220603 ]]]")
for i in range(1,13):
    print(i,"-",1)
    subtractImgs(i,1,date=date)
    print(i,"-",2)
    subtractImgs(i,2,date=date)
date = "20221020"
print(r"[[[ 20221020 ]]]")
for i in range(1,13):
    print(i,"-",1)
    subtractImgs(i,1,date=date)
    print(i,"-",2)
    subtractImgs(i,2,date=date)
# Out:
# [[[ 20220401 ]]]
# 1 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop\0501.jpg
# 501
# 1 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_2\crop\0501.jpg
# 501
# 2 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_1\crop\1051.jpg
# 1051
# 2 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\2_2\crop\1051.jpg
# 1051
# 3 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1051.jpg
# 1051
# 1100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1101.jpg
# 1101
# 1150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1151.jpg
# 1151
# 1200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1201.jpg
# 1201
# 1250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1251.jpg
# 1251
# 1300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1301.jpg
# 1301
# 1350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1351.jpg
# 1351
# 1400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1401.jpg
# 1401
# 1450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1451.jpg
# 1451
# 1500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1501.jpg
# 1501
# 1550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1551.jpg
# 1551
# 1600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1601.jpg
# 1601
# 1650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1651.jpg
# 1651
# 1700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1701.jpg
# 1701
# 1750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1751.jpg
# 1751
# 1800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1801.jpg
# 1801
# 1850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1851.jpg
# 1851
# 1900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1901.jpg
# 1901
# 1950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\1951.jpg
# 1951
# 2000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\2001.jpg
# 2001
# 2050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\2051.jpg
# 2051
# 2100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\2101.jpg
# 2101
# 2150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_1\crop\2151.jpg
# 2151
# 3 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1051.jpg
# 1051
# 1100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1101.jpg
# 1101
# 1150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1151.jpg
# 1151
# 1200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1201.jpg
# 1201
# 1250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1251.jpg
# 1251
# 1300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1301.jpg
# 1301
# 1350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1351.jpg
# 1351
# 1400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1401.jpg
# 1401
# 1450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1451.jpg
# 1451
# 1500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1501.jpg
# 1501
# 1550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1551.jpg
# 1551
# 1600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1601.jpg
# 1601
# 1650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1651.jpg
# 1651
# 1700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1701.jpg
# 1701
# 1750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1751.jpg
# 1751
# 1800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1801.jpg
# 1801
# 1850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1851.jpg
# 1851
# 1900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1901.jpg
# 1901
# 1950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\1951.jpg
# 1951
# 2000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\2001.jpg
# 2001
# 2050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\2051.jpg
# 2051
# 2100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\2101.jpg
# 2101
# 2150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\3_2\crop\2151.jpg
# 2151
# 4 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_1\crop\0501.jpg
# 501
# 4 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\4_2\crop\0501.jpg
# 501
# 5 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_1\crop\1051.jpg
# 1051
# 5 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\5_2\crop\1051.jpg
# 1051
# 6 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1051.jpg
# 1051
# 1100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1101.jpg
# 1101
# 1150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1151.jpg
# 1151
# 1200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1201.jpg
# 1201
# 1250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1251.jpg
# 1251
# 1300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1301.jpg
# 1301
# 1350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1351.jpg
# 1351
# 1400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1401.jpg
# 1401
# 1450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1451.jpg
# 1451
# 1500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1501.jpg
# 1501
# 1550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1551.jpg
# 1551
# 1600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1601.jpg
# 1601
# 1650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1651.jpg
# 1651
# 1700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1701.jpg
# 1701
# 1750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1751.jpg
# 1751
# 1800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1801.jpg
# 1801
# 1850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1851.jpg
# 1851
# 1900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1901.jpg
# 1901
# 1950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\1951.jpg
# 1951
# 2000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\2001.jpg
# 2001
# 2050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\2051.jpg
# 2051
# 2100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\2101.jpg
# 2101
# 2150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_1\crop\2151.jpg
# 2151
# 6 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1051.jpg
# 1051
# 1100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1101.jpg
# 1101
# 1150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1151.jpg
# 1151
# 1200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1201.jpg
# 1201
# 1250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1251.jpg
# 1251
# 1300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1301.jpg
# 1301
# 1350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1351.jpg
# 1351
# 1400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1401.jpg
# 1401
# 1450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1451.jpg
# 1451
# 1500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1501.jpg
# 1501
# 1550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1551.jpg
# 1551
# 1600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1601.jpg
# 1601
# 1650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1651.jpg
# 1651
# 1700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1701.jpg
# 1701
# 1750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1751.jpg
# 1751
# 1800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1801.jpg
# 1801
# 1850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1851.jpg
# 1851
# 1900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1901.jpg
# 1901
# 1950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\1951.jpg
# 1951
# 2000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\2001.jpg
# 2001
# 2050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\2051.jpg
# 2051
# 2100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\2101.jpg
# 2101
# 2150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\6_2\crop\2151.jpg
# 2151
# 7 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_1\crop\0501.jpg
# 501
# 7 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\7_2\crop\0501.jpg
# 501
# 8 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_1\crop\1051.jpg
# 1051
# 8 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\8_2\crop\1051.jpg
# 1051
# 9 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1051.jpg
# 1051
# 1100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1101.jpg
# 1101
# 1150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1151.jpg
# 1151
# 1200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1201.jpg
# 1201
# 1250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1251.jpg
# 1251
# 1300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1301.jpg
# 1301
# 1350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1351.jpg
# 1351
# 1400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1401.jpg
# 1401
# 1450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1451.jpg
# 1451
# 1500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1501.jpg
# 1501
# 1550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1551.jpg
# 1551
# 1600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1601.jpg
# 1601
# 1650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1651.jpg
# 1651
# 1700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1701.jpg
# 1701
# 1750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1751.jpg
# 1751
# 1800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1801.jpg
# 1801
# 1850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1851.jpg
# 1851
# 1900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1901.jpg
# 1901
# 1950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\1951.jpg
# 1951
# 2000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\2001.jpg
# 2001
# 2050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\2051.jpg
# 2051
# 2100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\2101.jpg
# 2101
# 2150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_1\crop\2151.jpg
# 2151
# 9 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1051.jpg
# 1051
# 1100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1101.jpg
# 1101
# 1150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1151.jpg
# 1151
# 1200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1201.jpg
# 1201
# 1250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1251.jpg
# 1251
# 1300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1301.jpg
# 1301
# 1350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1351.jpg
# 1351
# 1400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1401.jpg
# 1401
# 1450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1451.jpg
# 1451
# 1500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1501.jpg
# 1501
# 1550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1551.jpg
# 1551
# 1600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1601.jpg
# 1601
# 1650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1651.jpg
# 1651
# 1700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1701.jpg
# 1701
# 1750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1751.jpg
# 1751
# 1800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1801.jpg
# 1801
# 1850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1851.jpg
# 1851
# 1900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1901.jpg
# 1901
# 1950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\1951.jpg
# 1951
# 2000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\2001.jpg
# 2001
# 2050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\2051.jpg
# 2051
# 2100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\2101.jpg
# 2101
# 2150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\9_2\crop\2151.jpg
# 2151
# 10 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_1\crop\0501.jpg
# 501
# 10 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\10_2\crop\0501.jpg
# 501
# 11 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0851.jpg
# 851
# 900 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0901.jpg
# 901
# 950 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\0951.jpg
# 951
# 1000 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\1001.jpg
# 1001
# 1050 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_1\crop\1051.jpg
# 1051
# 11 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_2\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_2\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_2\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_2\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_2\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\11_2\crop\0251.jpg
# ...
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\29\crop\0851.jpg
# 851
# 5 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\30\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\30\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\30\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\30\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\30\crop\0201.jpg
# 201
# 6 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\31\crop\0301.jpg
# 301
# 6 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\32\crop\0851.jpg
# 851
# 7 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\33\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\33\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\33\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\33\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\33\crop\0201.jpg
# 201
# 7 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\34\crop\0401.jpg
# 401
# 8 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\35\crop\0851.jpg
# 851
# 8 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\36\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\36\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\36\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\36\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\36\crop\0201.jpg
# 201
# 9 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\37\crop\0401.jpg
# 401
# 9 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\38\crop\0851.jpg
# 851
# 10 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\39\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\39\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\39\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\39\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\39\crop\0201.jpg
# 201
# 10 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\40\crop\0401.jpg
# 401
# 11 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\41\crop\0851.jpg
# 851
# 11 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\42\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\42\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\42\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\42\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\42\crop\0201.jpg
# 201
# 12 - 1
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\43\crop\0401.jpg
# 401
# 12 - 2
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0451.jpg
# 451
# 500 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0501.jpg
# 501
# 550 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0551.jpg
# 551
# 600 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0601.jpg
# 601
# 650 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0651.jpg
# 651
# 700 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0701.jpg
# 701
# 750 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0751.jpg
# 751
# 800 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0801.jpg
# 801
# 850 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020\44\crop\0851.jpg
# 851

# %% [markdown]
# #concatenate imgs

# %%
def concatImg(x_patch = 3, y_patch = 3,INVERSE = True):
    h,w,c = 80,80,1
    H = h*3
    W = w*3
    concat = np.zeros((H,W,c))
    folder_path = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\1_1\crop'
    for i in range(9):
        file = "{:04d}.jpg".format(i+10)
        path = os.path.join(folder_path,file)
        img = cv2.imread(path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        img = np.expand_dims(np.array(img).astype("int32"),2)
        #new to old
        if INVERSE:
            row =  (x_patch-1) - i//3
            column = (y_patch-1) - i%3
            concat[h*row:h*(row+1),w*column:w*(column+1),:] = img
        #old to new
        else:
            row = i//3
            column = i%3
            concat[h*row:h*(row+1),w*column:w*(column+1),:] = img
    cv2.imwrite(r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401\concat_inverse.jpg',concat)

concatImg(INVERSE=True)

# %%
import numpy as np
import os
import csv
import random

class Dataset():
  def __init__(self,x_patch = 3, y_patch = 3, height = 80,width = 80,
                date = "20220401",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401',
                dir_concatImg = "concat_vit_subtraction"
              ):
    #num of patches
    self.x_patch = x_patch
    self.y_patch = y_patch  
    #size for 1 patch
    self.height = height
    self.width = width
    #size for concatenated img
    self.H = x_patch*height
    self.W = y_patch*width
    #date of dataset
    self.date = date
    #img src directory
    self.src_dir = src_dir
    #directory for concat img
    self.dir_concatImg = dir_concatImg
    #load spatter labels from .txt file
    if date == "20220401":
        dir=r'C:\Users\Furukawa\Documents\TechAssistant\Video\20220401\video'
        self.spatter_data_1_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(1,1)), dtype='int').tolist() #in coping with text file which divide data with space, remove delimiter params. 
        self.spatter_data_1_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(1,2)), dtype='int').tolist()
        self.spatter_data_2_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(2,1)), dtype='int').tolist()
        self.spatter_data_2_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(2,2)), dtype='int').tolist()
        self.spatter_data_3_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(3,1)), dtype='int').tolist()
        self.spatter_data_3_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(3,2)), dtype='int').tolist()
        self.spatter_data_4_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(4,1)), dtype='int').tolist()
        self.spatter_data_4_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(4,2)), dtype='int').tolist()
        self.spatter_data_5_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(5,1)), dtype='int').tolist()
        self.spatter_data_5_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(5,2)), dtype='int').tolist()
        self.spatter_data_6_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(6,1)), dtype='int').tolist()
        self.spatter_data_6_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(6,2)), dtype='int').tolist()
        self.spatter_data_7_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(7,1)), dtype='int').tolist()
        self.spatter_data_7_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(7,2)), dtype='int').tolist()
        self.spatter_data_8_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(8,1)), dtype='int').tolist()
        self.spatter_data_8_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(8,2)), dtype='int').tolist()
        self.spatter_data_9_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(9,1)), dtype='int').tolist()
        self.spatter_data_9_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(9,2)), dtype='int').tolist()
        self.spatter_data_10_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(10,1)), dtype='int').tolist()
        self.spatter_data_10_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(10,2)), dtype='int').tolist()
        self.spatter_data_11_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(11,1)),dtype='int').tolist()
        self.spatter_data_11_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(11,2)), dtype='int').tolist()
        self.spatter_data_12_1 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(12,1)), dtype='int').tolist()
        self.spatter_data_12_2 = np.loadtxt(os.path.join(dir,'220401_xiQ_{}-{}_spatter.txt'.format(12,2)), dtype='int').tolist()

    if date == "20220603":
        dir = r'C:\Users\Furukawa\Documents\TechAssistant\Video\20220603\video'
        head  = "xiQ_20220603"
        self.spatter_data_1_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,1,1)), dtype='int').tolist()
        self.spatter_data_1_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,1,2)), dtype='int').tolist()
        self.spatter_data_2_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,2,1)), dtype='int').tolist()
        self.spatter_data_2_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,2,2)), dtype='int').tolist()
        self.spatter_data_3_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,3,1)), dtype='int').tolist()
        self.spatter_data_3_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,3,2)), dtype='int').tolist()
        self.spatter_data_4_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,4,1)), dtype='int').tolist()
        self.spatter_data_4_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,4,2)), dtype='int').tolist()
        self.spatter_data_5_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,5,1)), dtype='int').tolist()
        self.spatter_data_5_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,5,2)), dtype='int').tolist()
        self.spatter_data_6_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,6,1)), dtype='int').tolist()
        self.spatter_data_6_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,6,2)), dtype='int').tolist()
        self.spatter_data_7_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,7,1)), dtype='int').tolist()
        self.spatter_data_7_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,7,2)), dtype='int').tolist()
        self.spatter_data_8_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,8,1)), dtype='int').tolist()
        self.spatter_data_8_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,8,2)), dtype='int').tolist()
        self.spatter_data_9_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,9,1)), dtype='int').tolist()
        self.spatter_data_9_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,9,2)), dtype='int').tolist()
        self.spatter_data_10_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,10,1)), dtype='int').tolist()
        self.spatter_data_10_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,10,2)), dtype='int').tolist()
        self.spatter_data_11_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,11,1)), dtype='int').tolist()
        self.spatter_data_11_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,11,2)), dtype='int').tolist()
        self.spatter_data_12_1 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,12,1)), dtype='int').tolist()
        self.spatter_data_12_2 = np.loadtxt(os.path.join(dir,'{}_{}-{}_spatter.txt'.format(head,12,2)), dtype='int').tolist()
    
    if date == "20221020":
        dir = r'C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video'
        head  = "XIMEA_221020"
        self.spatter_data_1_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,21)), dtype='int').tolist()
        self.spatter_data_1_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,22)), dtype='int').tolist()
        self.spatter_data_2_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,23)), dtype='int').tolist()
        self.spatter_data_2_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,24)), dtype='int').tolist()
        self.spatter_data_3_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,25)), dtype='int').tolist()
        self.spatter_data_3_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,26)), dtype='int').tolist()
        self.spatter_data_4_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,27)), dtype='int').tolist()
        self.spatter_data_4_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,28)), dtype='int').tolist()
        self.spatter_data_5_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,29)), dtype='int').tolist()
        self.spatter_data_5_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,30)), dtype='int').tolist()
        self.spatter_data_6_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,31)), dtype='int').tolist()
        self.spatter_data_6_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,32)), dtype='int').tolist()
        self.spatter_data_7_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,33)), dtype='int').tolist()
        self.spatter_data_7_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,34)), dtype='int').tolist()
        self.spatter_data_8_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,35)), dtype='int').tolist()
        self.spatter_data_8_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,36)), dtype='int').tolist()
        self.spatter_data_9_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,37)), dtype='int').tolist()
        self.spatter_data_9_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,38)), dtype='int').tolist()
        self.spatter_data_10_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,39)), dtype='int').tolist()
        self.spatter_data_10_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,40)), dtype='int').tolist()
        self.spatter_data_11_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,41)), dtype='int').tolist()
        self.spatter_data_11_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,42)), dtype='int').tolist()
        self.spatter_data_12_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,43)), dtype='int').tolist()
        self.spatter_data_12_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,44)), dtype='int').tolist()

  def concatImg(self,index,src_img_dir,save_dir,INVERSE = False):
      """concatenate images
      Args:
        index: index for spatter frame, so index is the latest index in 9 frames, ie. index, index-1,index-2,..., index-8
        src_img_dir : source directory of cropped imgs
        save_dir : save dir for concatenate images
        x_patch, y_patch : number of patches in x and y axis
        INVERSE : patch order. If INVERSE is True, new to old is applied
      Return:
        file_path : path for concat img
        write concatenated images into designated directory
      """
      concat = np.zeros((self.H,self.W,1))
      for i in range(9):
          file = "{:04d}.jpg".format(index-i) #from new to old
          path = os.path.join(src_img_dir,file)
          img = cv2.imread(path)
          img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #gray scale
          img = np.expand_dims(np.array(img).astype("int32"),2) #add color channel : (height,width,1)
          #new to old
          if INVERSE:
              row = i//3
              column = i%3
              concat[self.height*row:self.height*(row+1),self.width*column:self.width*(column+1),:] = img
          #old to new
          else:
              row =  (self.x_patch-1) - i//3
              column = (self.y_patch-1) - i%3
              concat[self.height*row:self.height*(row+1),self.width*column:self.width*(column+1),:] = img
      file_path = os.path.join(save_dir,f"{index:04d}.jpg")
      cv2.imwrite(file_path,concat)
      return file_path

  def checkImg(self,file_path):
    """check whether laser process has started

    Args:
        file_path (str): img file path
    """
    img = cv2.imread(file_path)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = gray
    ret,thresh = cv2.threshold(gray,10,255,cv2.THRESH_BINARY)
    #find contours
    contours, hierarchy = cv2.findContours(np.array(thresh,dtype=uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    Area = []
    #detect laser area
    if (bool(contours)==True):
      #面積(px*px)
      for j in contours:
        area = cv2.contourArea(j)
        Area.append(area)

      if Area:
        area_max = np.max(Area)
        if area_max > 4:
           ret = True
           return ret
        else:
           ret = False
           return ret
      else:
         ret = False
         return ret
      
  # adjust the number of no spatter below 51
  def make(self,filename,filename_test,div,sec):
    #フォルダに存在するファイルを取得する、0001.jpg~0005.jpg→{}/*.jpg
    
    #spatter label 
    if self.date == "20220401":
      spatter = [[[],[]],
                [self.spatter_data_1_1,self.spatter_data_1_2],
                [self.spatter_data_2_1,self.spatter_data_2_2],
                [self.spatter_data_3_1,self.spatter_data_3_2],
                [self.spatter_data_4_1,self.spatter_data_4_2],
                [self.spatter_data_5_1,self.spatter_data_5_2],
                [self.spatter_data_6_1,self.spatter_data_6_2],
                [self.spatter_data_7_1,self.spatter_data_7_2],
                [self.spatter_data_8_1,self.spatter_data_8_2],
                [self.spatter_data_9_1,self.spatter_data_9_2],
                [self.spatter_data_10_1,self.spatter_data_10_2],
                [self.spatter_data_11_1,self.spatter_data_11_2],
                [self.spatter_data_12_1,self.spatter_data_12_2]]
    elif self.date == "20220603":
       spatter = [[[],[]],
                [self.spatter_data_1_1,self.spatter_data_1_2],
                [self.spatter_data_2_1,self.spatter_data_2_2],
                [self.spatter_data_3_1,self.spatter_data_3_2],
                [[self.spatter_data_4_1],self.spatter_data_4_2],
                [self.spatter_data_5_1,self.spatter_data_5_2],
                [self.spatter_data_6_1,self.spatter_data_6_2],
                [[self.spatter_data_7_1],[self.spatter_data_7_2]],
                [self.spatter_data_8_1,self.spatter_data_8_2],
                [self.spatter_data_9_1,self.spatter_data_9_2],
                [self.spatter_data_10_1,self.spatter_data_10_2],
                [self.spatter_data_11_1,self.spatter_data_11_2],
                [self.spatter_data_12_1,self.spatter_data_12_2]]
    elif self.date == "20221020":
       spatter = [[[],[]],
                [self.spatter_data_1_1,self.spatter_data_1_2],
                [[self.spatter_data_2_1],self.spatter_data_2_2],
                [self.spatter_data_3_1,[self.spatter_data_3_2]],
                [[self.spatter_data_4_1],[self.spatter_data_4_2]],
                [self.spatter_data_5_1,[self.spatter_data_5_2]],
                [self.spatter_data_6_1,self.spatter_data_6_2],
                [self.spatter_data_7_1,[self.spatter_data_7_2]],
                [[self.spatter_data_8_1],[self.spatter_data_8_2]],
                [[self.spatter_data_9_1],self.spatter_data_9_2],
                [self.spatter_data_10_1,[self.spatter_data_10_2]],
                [self.spatter_data_11_1,[self.spatter_data_11_2]],
                [self.spatter_data_12_1,self.spatter_data_12_2]]
    
    if self.date == "20220401"  or self.date == "20220603":
      #set src img directory
      src_img_dir = os.path.join(self.src_dir,"{}_{}\crop\subtraction".format(div,sec))
      #make save directory
      save_dir= os.path.join(self.src_dir,"{}_{}\{}".format(div,sec,self.dir_concatImg))
      if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    elif self.date == "20221020":
      #set src img directory
      src_img_dir = os.path.join(self.src_dir,"{}\crop\subtraction".format((div-1)*2+sec+20))
      #make save directory
      save_dir= os.path.join(self.src_dir,"{}\{}".format(((div-1)*2+sec+20),self.dir_concatImg))
      if not os.path.exists(save_dir):
        os.mkdir(save_dir)

    #spatter count
    count_spatter = 0
    count_nonspatter = 0
    #get num of file in a directory
    num_photo = sum(os.path.isfile(os.path.join(src_img_dir,name)) for name in os.listdir(src_img_dir))
    print("{}-{} progressing :: {}".format(div,sec,num_photo))
    #make dataset
    for i in range(10,num_photo-10):
      file_path = os.path.join(src_img_dir,f"{i:04d}.jpg")
      ret = self.checkImg(file_path=file_path)
      #laser welding has started
      if ret :
        #spater frame
        if (((i+10) in spatter[div-1][sec-1]) or ((i+9) in spatter[div-1][sec-1]) or ((i+8) in spatter[div-1][sec-1]) or 
            ((i+7) in spatter[div-1][sec-1]) or ((i+6) in spatter[div-1][sec-1]) or ((i+5) in spatter[div-1][sec-1]) or 
            ((i+4) in spatter[div-1][sec-1]) or ((i+3) in spatter[div-1][sec-1]) or ((i+2) in spatter[div-1][sec-1])):  
          #whether spatter frame is included in input frame
          if ((i not in spatter[div-1][sec-1]) and ((i-1) not in spatter[div-1][sec-1]) and ((i-2) not in spatter[div-1][sec-1]) and 
              ((i-3) not in spatter[div-1][sec-1]) and ((i-4) not in spatter[div-1][sec-1]) and ((i-5) not in spatter[div-1][sec-1]) and 
            ((i-6) not in spatter[div-1][sec-1]) and ((i-7) not in spatter[div-1][sec-1]) and ((i-8) not in spatter[div-1][sec-1])) :
            #concatenate images
            file_path = self.concatImg(index=i,src_img_dir=src_img_dir,save_dir=save_dir,INVERSE = False)
            if random.random() >= 0.1: #85% is train data
              with open(filename,"a",newline='') as f:
                writer = csv.writer(f)
                writer.writerow([1,file_path])
            else:
              with open(filename_test,"a",newline='') as f:
                  writer = csv.writer(f)
                  writer.writerow([1,file_path])
            count_spatter += 1
        #non-spatter frame
        else:
          #whether spatter frame is included in input frame
          if ((i not in spatter[div-1][sec-1]) and ((i-1) not in spatter[div-1][sec-1]) and ((i-2) not in spatter[div-1][sec-1]) and 
              ((i-3) not in spatter[div-1][sec-1]) and ((i-4) not in spatter[div-1][sec-1]) and ((i-5) not in spatter[div-1][sec-1]) and 
            ((i-6) not in spatter[div-1][sec-1]) and ((i-7) not in spatter[div-1][sec-1]) and ((i-8) not in spatter[div-1][sec-1])) :
            #random function for variety of dataset
            if random.random() >= 0.95:
              #concatenate images
              file_path = self.concatImg(index=i,src_img_dir=src_img_dir,save_dir=save_dir,INVERSE = False)
              if random.random() >= 0.1: #85% is train data
                with open(filename,"a",newline='') as f:
                  writer = csv.writer(f)
                  writer.writerow([0,file_path])
              else:
                with open(filename_test,"a",newline='') as f:
                  writer = csv.writer(f)
                  writer.writerow([0,file_path])
              count_nonspatter += 1
    print(f"Finished! Spatter :: {count_spatter}, Non-spatter :: {count_nonspatter}")

# %% [markdown]
# #20220401

# %% [markdown]
# #Initialize dataset file

# %%
import csv







#Initialize csv dataset?
INITIALIZE = True



#prepare csv files
file_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\csv\ViT'
filename=os.path.join(file_dir,"train_vitSubtraction.csv")
filename_test=os.path.join(file_dir,"test_vitSubtraction.csv")
#///////////////////
if INITIALIZE:
  #make csv file
  with open(filename,"w") as f:
    writer = csv.writer(f)
    writer.writerow(["Spatter","Path"])

  with open(filename_test,"w") as f:
    writer = csv.writer(f)
    writer.writerow(["Spatter","Path"])

# %%
dataset = Dataset(x_patch = 3, y_patch = 3, height = 80,width = 80,
                date = "20220401",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401',
                dir_concatImg = "concat_vitSubtraction"
                )

#make dataset one by one
for i in range(1,13):
  for j in range(1,3):
    dataset.make(filename=filename,filename_test=filename_test,div = i,sec = j)
# Out:
# 1-1 progressing :: 539
# Finished! Spatter :: 0, Non-spatter :: 23
# 1-2 progressing :: 536
# Finished! Spatter :: 0, Non-spatter :: 23
# 2-1 progressing :: 1079
# Finished! Spatter :: 36, Non-spatter :: 37
# 2-2 progressing :: 1078
# Finished! Spatter :: 28, Non-spatter :: 45
# 3-1 progressing :: 2161
# Finished! Spatter :: 105, Non-spatter :: 53
# 3-2 progressing :: 2161
# Finished! Spatter :: 123, Non-spatter :: 68
# 4-1 progressing :: 539
# Finished! Spatter :: 43, Non-spatter :: 23
# 4-2 progressing :: 539
# Finished! Spatter :: 31, Non-spatter :: 15
# 5-1 progressing :: 1079
# Finished! Spatter :: 54, Non-spatter :: 32
# 5-2 progressing :: 1080
# Finished! Spatter :: 31, Non-spatter :: 46
# 6-1 progressing :: 2162
# Finished! Spatter :: 149, Non-spatter :: 61
# 6-2 progressing :: 2161
# Finished! Spatter :: 158, Non-spatter :: 91
# 7-1 progressing :: 539
# Finished! Spatter :: 71, Non-spatter :: 15
# 7-2 progressing :: 539
# Finished! Spatter :: 65, Non-spatter :: 21
# 8-1 progressing :: 1081
# Finished! Spatter :: 42, Non-spatter :: 52
# 8-2 progressing :: 1078
# Finished! Spatter :: 54, Non-spatter :: 36
# 9-1 progressing :: 2160
# Finished! Spatter :: 172, Non-spatter :: 62
# 9-2 progressing :: 2161
# Finished! Spatter :: 162, Non-spatter :: 75
# 10-1 progressing :: 539
# Finished! Spatter :: 56, Non-spatter :: 17
# 10-2 progressing :: 539
# Finished! Spatter :: 53, Non-spatter :: 16
# 11-1 progressing :: 1079
# Finished! Spatter :: 41, Non-spatter :: 37
# 11-2 progressing :: 1079
# Finished! Spatter :: 50, Non-spatter :: 34
# 12-1 progressing :: 2160
# Finished! Spatter :: 160, Non-spatter :: 53
# 12-2 progressing :: 2091
# Finished! Spatter :: 170, Non-spatter :: 54

# %% [markdown]
# #check dataset

# %%
import pandas as pd
file_train = pd.read_csv(filename)
train = file_train.values
print(train.shape)
file_test = pd.read_csv(filename_test)
test = file_test.values
print(test.shape)
# Out:
# (2570, 2)
# (273, 2)

# %% [markdown]
# #20220603

# %%
dataset = Dataset(x_patch = 3, y_patch = 3, height = 80,width = 80,
                date = "20220603",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220603',
                dir_concatImg = "concat_vitSubtraction"
                )

#make dataset one by one
for i in range(1,13):
  for j in range(1,3):
    dataset.make(filename=filename,filename_test=filename_test,div = i,sec = j)
# Out:
# 1-1 progressing :: 539
# Finished! Spatter :: 0, Non-spatter :: 23
# 1-2 progressing :: 532
# Finished! Spatter :: 0, Non-spatter :: 19
# 2-1 progressing :: 1078
# Finished! Spatter :: 9, Non-spatter :: 34
# 2-2 progressing :: 1079
# Finished! Spatter :: 8, Non-spatter :: 39
# 3-1 progressing :: 2161
# Finished! Spatter :: 8, Non-spatter :: 91
# 3-2 progressing :: 2162
# Finished! Spatter :: 18, Non-spatter :: 79
# 4-1 progressing :: 456
# Finished! Spatter :: 21, Non-spatter :: 17
# 4-2 progressing :: 539
# Finished! Spatter :: 18, Non-spatter :: 20
# 5-1 progressing :: 1078
# Finished! Spatter :: 0, Non-spatter :: 44
# 5-2 progressing :: 1079
# Finished! Spatter :: 18, Non-spatter :: 40
# 6-1 progressing :: 2161
# Finished! Spatter :: 17, Non-spatter :: 73
# 6-2 progressing :: 2161
# Finished! Spatter :: 33, Non-spatter :: 86
# 7-1 progressing :: 540
# Finished! Spatter :: 23, Non-spatter :: 23
# 7-2 progressing :: 539
# Finished! Spatter :: 28, Non-spatter :: 17
# 8-1 progressing :: 1079
# Finished! Spatter :: 0, Non-spatter :: 45
# 8-2 progressing :: 1079
# Finished! Spatter :: 0, Non-spatter :: 36
# 9-1 progressing :: 2161
# Finished! Spatter :: 10, Non-spatter :: 112
# 9-2 progressing :: 2162
# Finished! Spatter :: 40, Non-spatter :: 77
# 10-1 progressing :: 538
# Finished! Spatter :: 24, Non-spatter :: 19
# 10-2 progressing :: 538
# Finished! Spatter :: 54, Non-spatter :: 16
# 11-1 progressing :: 1079
# Finished! Spatter :: 19, Non-spatter :: 38
# 11-2 progressing :: 1078
# Finished! Spatter :: 9, Non-spatter :: 48
# 12-1 progressing :: 2161
# Finished! Spatter :: 55, Non-spatter :: 96
# 12-2 progressing :: 2161
# Finished! Spatter :: 85, Non-spatter :: 79

# %%
import pandas as pd
file_train = pd.read_csv(filename)
train = file_train.values
print(train.shape)
file_test = pd.read_csv(filename_test)
test = file_test.values
print(test.shape)
# Out:
# (4085, 2)
# (426, 2)

# %% [markdown]
# #20221020

# %%
dataset = Dataset(x_patch = 3, y_patch = 3, height = 80,width = 80,
                date = "20221020",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20221020',
                dir_concatImg = "concat_vitSubtraction"
                )

#make dataset one by one
for i in range(1,13):
  for j in range(1,3):
    dataset.make(filename=filename,filename_test=filename_test,div = i,sec = j)
# Out:
# 1-1 progressing :: 243
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_27616\4223940709.py:86: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video\XIMEA_221020_21_trim_spatter.txt"
#   self.spatter_data_1_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,21)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_27616\4223940709.py:87: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video\XIMEA_221020_22_trim_spatter.txt"
#   self.spatter_data_1_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,22)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_27616\4223940709.py:89: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video\XIMEA_221020_24_trim_spatter.txt"
#   self.spatter_data_2_2 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,24)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_27616\4223940709.py:90: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video\XIMEA_221020_25_trim_spatter.txt"
#   self.spatter_data_3_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,25)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_27616\4223940709.py:98: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video\XIMEA_221020_33_trim_spatter.txt"
#   self.spatter_data_7_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,33)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_27616\4223940709.py:104: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20221020\video\XIMEA_221020_39_trim_spatter.txt"
#   self.spatter_data_10_1 = np.loadtxt(os.path.join(dir,'{}_{}_trim_spatter.txt'.format(head,39)), dtype='int').tolist()
# Finished! Spatter :: 0, Non-spatter :: 2
# 1-2 progressing :: 447
# Finished! Spatter :: 0, Non-spatter :: 15
# 2-1 progressing :: 894
# Finished! Spatter :: 0, Non-spatter :: 38
# 2-2 progressing :: 244
# Finished! Spatter :: 0, Non-spatter :: 12
# 3-1 progressing :: 447
# Finished! Spatter :: 0, Non-spatter :: 19
# 3-2 progressing :: 862
# Finished! Spatter :: 0, Non-spatter :: 43
# 4-1 progressing :: 234
# Finished! Spatter :: 0, Non-spatter :: 11
# 4-2 progressing :: 429
# Finished! Spatter :: 9, Non-spatter :: 25
# 5-1 progressing :: 856
# Finished! Spatter :: 9, Non-spatter :: 36
# 5-2 progressing :: 232
# Finished! Spatter :: 6, Non-spatter :: 6
# 6-1 progressing :: 311
# Finished! Spatter :: 0, Non-spatter :: 13
# 6-2 progressing :: 879
# Finished! Spatter :: 0, Non-spatter :: 38
# 7-1 progressing :: 235
# Finished! Spatter :: 7, Non-spatter :: 7
# 7-2 progressing :: 433
# Finished! Spatter :: 21, Non-spatter :: 16
# 8-1 progressing :: 865
# Finished! Spatter :: 0, Non-spatter :: 42
# 8-2 progressing :: 239
# Finished! Spatter :: 9, Non-spatter :: 5
# 9-1 progressing :: 439
# Finished! Spatter :: 9, Non-spatter :: 17
# 9-2 progressing :: 882
# Finished! Spatter :: 9, Non-spatter :: 35
# 10-1 progressing :: 239
# Finished! Spatter :: 9, Non-spatter :: 13
# 10-2 progressing :: 441
# Finished! Spatter :: 18, Non-spatter :: 18
# 11-1 progressing :: 888
# Finished! Spatter :: 0, Non-spatter :: 36
# 11-2 progressing :: 241
# Finished! Spatter :: 0, Non-spatter :: 16
# 12-1 progressing :: 446
# Finished! Spatter :: 65, Non-spatter :: 17
# 12-2 progressing :: 891
# Finished! Spatter :: 0, Non-spatter :: 50

# %%
import pandas as pd
file_train = pd.read_csv(filename)
train = file_train.values
print(train.shape)
file_test = pd.read_csv(filename_test)
test = file_test.values
print(test.shape)
# Out:
# (4710, 2)
# (502, 2)

# %% [markdown]
# # total dataset

# %%
import pandas as pd
file_train = pd.read_csv(filename)
train = file_train.values
labels_train = train[:,0]
print(train.shape)
file_test = pd.read_csv(filename_test)
test = file_test.values
labels_test = test[:,0]
print(test.shape)
def count_spatter(labels):
    count = 0
    for i in range(labels.shape[0]):
        if labels[i] == 1:
            count += 1
    print(f"Spatter/total : {count}/{labels.shape[0]}")

print("train data")
count_spatter(labels_train)
print("test data")
count_spatter(labels_test)
# Out:
# (4710, 2)
# (502, 2)
# train data
# Spatter/total : 2278/4710
# test data
# Spatter/total : 244/502
